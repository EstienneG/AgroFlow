# %% [markdown]
# # Generate synthetic data for training

# %%
from mistralai import Field, Mistral
import os
from prompts import get_prompt_for_theme
import asyncio
from tqdm import tqdm
import random
import nest_asyncio
from pydantic import BaseModel
from typing import List
from tqdm.asyncio import tqdm_asyncio

nest_asyncio.apply()

MISTRAL_API_KEY=os.getenv("MISTRAL_API_KEY")
client = Mistral(api_key=MISTRAL_API_KEY)

class Questions(BaseModel):
    questions: List[str] = Field(..., description="Une liste de questions à propos d'un thème donné")


async def _generate_queries(theme):
    await asyncio.sleep(random.uniform(0, 10))

    prompt = get_prompt_for_theme(theme)

    response = await client.chat.parse_async(
        model="mistral-large-latest",
        messages=[
            {"role": "user", "content": prompt}
        ],
        response_format=Questions
    )
    return {"questions":response.choices[0].message.parsed.questions, "theme": theme}


async def main():
    themes = ["market_question", "policy_help", "disease_diagnosis", "weather_management", "other"]
    all_tasks = []

    for theme in themes:
        print(f"Setting up tasks for theme: {theme}")
        all_tasks.extend([_generate_queries(theme) for _ in range(30)])
    
    total_tasks = len(all_tasks)
    print(f"Processing {total_tasks} tasks in batches of 20")
    
    results = []
    batch_size = 20

    for i in range(0, total_tasks, batch_size):
        batch_tasks = all_tasks[i:i+batch_size]
        print(f"Processing batch {i//batch_size + 1} ({len(batch_tasks)} tasks)")
        
        try:
            batch_results = await tqdm_asyncio.gather(*batch_tasks)
            results.extend(batch_results)

        except Exception as e:
            print(f"Error in batch {i//batch_size + 1}: {e}")
            continue



    return results

q_theme_df = asyncio.run(main())

q_theme_df
# Out:
# Setting up tasks for theme: market_question
# Setting up tasks for theme: policy_help
# Setting up tasks for theme: disease_diagnosis
# Setting up tasks for theme: weather_management
# Setting up tasks for theme: other
# Processing 150 tasks in batches of 20
# Processing batch 1 (20 tasks)
# 100%|██████████| 20/20 [00:25<00:00,  1.26s/it]
# Processing batch 2 (20 tasks)
# 100%|██████████| 20/20 [00:29<00:00,  1.48s/it]
# Processing batch 3 (20 tasks)
# 100%|██████████| 20/20 [00:22<00:00,  1.13s/it]
# Processing batch 4 (20 tasks)
# 100%|██████████| 20/20 [00:23<00:00,  1.16s/it]
# Processing batch 5 (20 tasks)
# 100%|██████████| 20/20 [00:18<00:00,  1.05it/s]
# Processing batch 6 (20 tasks)
# 100%|██████████| 20/20 [00:30<00:00,  1.52s/it]
# Processing batch 7 (20 tasks)
# 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# Processing batch 8 (10 tasks)
# 100%|██████████| 10/10 [00:19<00:00,  1.96s/it]
# [{'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de soja ?',
#    'Quel est le prix de référence du blé ?',
#    'Quelle est la répartition des volumes collectés pour les pommes de terre en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de riz de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quelles sont les prévisions de demande pour le lait en 2024 ?',
#    'Quelle est la tendance du marché pour les agrumes en 2024 ?',
#    'Quel est le prix moyen du bœuf au kilo en 2024 ?',
#    'Quelle région a enregistré la plus forte baisse de la production de betteraves sucrières ?',
#    'Quelle est la part de marché des producteurs locaux de fruits et légumes en 2024 ?',
#    'Quelles sont les principales menaces concurrentielles pour les producteurs de céréales en 2024 ?',
#    "Quel est l'impact des politiques agricoles sur les prix du maïs en 2024 ?",
#    'Quelle est la demande prévue pour les produits laitiers en 2024 ?',
#    'Quelle est la répartition des exportations de viande bovine par région en 2024 ?',
#    'Quel est le prix de vente moyen des tomates en 2024 ?',
#    'Quelle est la production de blé dur en 2024 par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la production de pommes ?',
#    'Quel est le prix de référence du coton en 2024 ?',
#    'Quelle est la répartition des volumes collectés pour les olives en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des importations de café de l'UE par rapport à l'année précédente au 3 mars 2024 ?"],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de soja ?',
#    'Quel est le prix de référence du blé tendre ?',
#    'Quelle est la répartition des volumes collectés pour les pommes de terre en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de riz de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quelle est la tendance du marché pour les fruits exotiques en 2024 ?',
#    "Quel est l'impact des politiques agricoles sur les prix des produits laitiers ?",
#    'Quelles sont les prévisions de demande pour le coton en 2025 ?',
#    'Quelle est la situation actuelle du marché des oléagineux ?',
#    'Quelle est la concurrence entre les producteurs de viande bovine en Europe ?',
#    'Quel est le prix moyen du lait en 2024 ?',
#    'Quelle est la production de vin en France en 2024 ?',
#    'Quelle est la demande de produits biologiques en 2024 ?',
#    "Quel est l'impact des conditions climatiques sur la production de céréales en 2024 ?",
#    'Quelle est la situation du marché des légumes bio en Europe ?',
#    "Quel est le prix de référence de l'huile d'olive en 2024 ?",
#    'Quelle est la production de pommes en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de betteraves sucrières ?',
#    'Quel est le prix de référence du café en 2024 ?',
#    'Quelle est la répartition des volumes collectés pour les agrumes en 2024 par rapport à la moyenne quinquennale 2018-2023 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de blé en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de maïs ?',
#    'Quel est le prix de référence du lait ?',
#    'Quelle est la répartition des volumes collectés pour les pommes de terre en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de soja de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quelles sont les prévisions de demande pour le riz en 2025 ?',
#    'Quelle est la tendance actuelle des prix des engrais ?',
#    'Quels sont les principaux importateurs de café en 2024 ?',
#    "Quelle est l'évolution des prix du cacao au cours des cinq dernières années ?",
#    'Quels sont les principaux défis du marché du coton en 2024 ?',
#    'Quelle est la production de betterave sucrière en 2024 ?',
#    'Quelle est la demande prévue pour les légumes bio en 2025 ?',
#    'Quels sont les principaux exportateurs de viande bovine en 2024 ?',
#    'Quelle est la tendance des prix du porc en 2024 ?',
#    'Quelle est la production de pommes en 2024 ?',
#    'Quelle est la demande prévue pour les produits laitiers en 2025 ?',
#    'Quels sont les principaux importateurs de vin en 2024 ?',
#    "Quelle est l'évolution des prix de l'huile d'olive au cours des cinq dernières années ?",
#    'Quels sont les principaux défis du marché des agrumes en 2024 ?',
#    'Quelle est la production de tomates en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelles sont les prévisions de demande pour le maïs en 2025 ?',
#    'Quel est le prix moyen du lait en Europe en 2024 ?',
#    'Quelle est la tendance actuelle du marché des oléagineux ?',
#    'Quels sont les principaux concurrents sur le marché du blé en France ?',
#    'Quelle est la variation des importations de soja en Chine en 2024 ?',
#    "Quel est l'impact des politiques agricoles sur le prix du riz ?",
#    'Quelle est la production de pommes de terre en 2024 par rapport à 2023 ?',
#    'Quels sont les facteurs influençant le marché du café en 2024 ?',
#    'Quelle est la répartition des exportations de viande bovine en 2024 ?',
#    'Quel est le prix de référence du coton en 2024 ?',
#    'Quelle région a enregistré la plus forte baisse de la production de maïs ?',
#    'Quelle est la demande prévue pour les légumes bio en 2025 ?',
#    "Quel est l'impact des conditions météorologiques sur le marché du sucre ?",
#    'Quelle est la tendance du marché des fruits exotiques en 2024 ?',
#    'Quels sont les défis actuels du marché des produits laitiers ?',
#    'Quelle est la production de vin en France en 2024 ?',
#    "Quel est l'impact de la pandémie sur le marché des céréales ?",
#    'Quelle est la variation des prix des engrais en 2024 ?',
#    'Quels sont les principaux exportateurs de café en 2024 ?',
#    'Quelle est la demande prévue pour les produits biologiques en 2025 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle du prix du blé sur le marché mondial ?',
#    'Quels sont les principaux facteurs influençant la demande de maïs en Europe ?',
#    'Comment la production de soja a-t-elle évolué en Amérique du Sud ces dernières années ?',
#    "Quels sont les prévisions de prix pour le riz en Asie pour l'année prochaine ?",
#    'Quelle est la répartition des exportations de céréales par pays en 2024 ?',
#    'Quels sont les principaux défis auxquels sont confrontés les producteurs de lait en France ?',
#    'Comment les politiques commerciales impactent-elles le marché du coton ?',
#    'Quelle est la situation actuelle du marché des engrais en Afrique ?',
#    'Quels sont les principaux concurrents sur le marché mondial du café ?',
#    'Comment la demande de viande bovine évolue-t-elle en Amérique du Nord ?',
#    'Quelle est la production de pommes de terre en Europe en 2024 ?',
#    'Quels sont les facteurs influençant le prix du sucre sur le marché international ?',
#    'Comment les conditions météorologiques affectent-elles la production de blé en Australie ?',
#    'Quelle est la tendance des importations de fruits et légumes en Europe ?',
#    "Quels sont les principaux marchés pour l'exportation de vin français ?",
#    "Comment la production de cacao a-t-elle évolué en Afrique de l'Ouest ?",
#    'Quelle est la situation actuelle du marché des oléagineux en Amérique du Sud ?',
#    'Quels sont les prévisions de demande pour le lait en poudre en Asie ?',
#    'Comment les innovations technologiques impactent-elles le marché agricole ?',
#    'Quelle est la répartition des volumes collectés pour les légumineuses en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle des prix du maïs sur le marché mondial ?',
#    'Quels sont les principaux facteurs influençant la demande de soja en 2024 ?',
#    'Comment les politiques commerciales affectent-elles les exportations de riz cette année ?',
#    'Quelle est la prévision de production de blé pour la saison 2024-2025 ?',
#    'Quels sont les principaux concurrents sur le marché des pommes de terre en Europe ?',
#    "Quelle est la variation du prix du lait par rapport à l'année précédente ?",
#    'Quels sont les défis actuels pour les producteurs de coton en Afrique ?',
#    'Quelle est la demande prévue pour les fruits tropicaux en 2024 ?',
#    'Comment les conditions météorologiques ont-elles affecté la production de café en Amérique du Sud ?',
#    'Quelle est la répartition des exportations de viande bovine par pays en 2024 ?',
#    'Quels sont les impacts de la demande croissante de produits biologiques sur le marché agricole ?',
#    'Quelle est la tendance des prix des engrais en 2024 ?',
#    "Quels sont les principaux marchés d'exportation pour les produits laitiers français ?",
#    "Quelle est la production de céréales en Russie pour l'année 2024 ?",
#    'Comment les innovations technologiques influencent-elles la production agricole ?',
#    'Quelle est la demande de légumes biologiques en Europe en 2024 ?',
#    "Quels sont les défis logistiques pour l'exportation de fruits frais ?",
#    'Quelle est la situation du marché des oléagineux en 2024 ?',
#    'Quels sont les principaux importateurs de maïs en 2024 ?',
#    "Quelle est la variation des prix du sucre par rapport à l'année précédente ?"],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de colza ?',
#    'Quel est le prix de référence du blé dur ?',
#    'Quelle est la répartition des volumes collectés pour les pommes de terre en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de soja de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quels sont les principaux facteurs influençant le prix du lait en 2024 ?',
#    'Quelle est la tendance des importations de riz en Europe pour 2024 ?',
#    'Quelle est la demande prévue pour les légumes bio en 2024 ?',
#    'Quelles sont les prévisions de production de viande bovine en 2024 ?',
#    "Quel est l'impact des conditions météorologiques sur la production de fruits en 2024 ?",
#    'Quelle est la part de marché des producteurs locaux de fromage en 2024 ?',
#    'Quelles sont les perspectives de croissance pour le marché des produits laitiers en 2024 ?',
#    'Quel est le niveau de stock de céréales en Europe au début de 2024 ?',
#    'Quelle est la consommation prévue de produits de la pêche en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché du sucre en 2024 ?',
#    'Quelle est la tendance des prix des engrais pour 2024 ?',
#    'Quelle est la production prévue de vin en France pour 2024 ?',
#    "Quels sont les défis logistiques pour l'exportation de produits agricoles en 2024 ?",
#    'Quelle est la demande prévue pour les produits agricoles biologiques en 2024 ?',
#    'Quelle est la tendance des prix des légumes frais en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production mondiale de maïs en 2024 ?',
#    'Quel est le prix actuel du blé sur le marché européen ?',
#    'Quelles sont les prévisions de demande pour le soja en 2025 ?',
#    'Quelle région a enregistré la plus forte baisse de la production de riz en 2024 ?',
#    'Quel est le taux de croissance annuel moyen du marché des légumes bio depuis 2020 ?',
#    'Quelle est la part de marché des producteurs locaux de pommes en France ?',
#    'Quels sont les principaux facteurs influençant les prix des produits laitiers en 2024 ?',
#    "Quelle est la répartition des exportations de viande bovine de l'Argentine en 2024 ?",
#    'Quel est le prix de référence actuel pour le coton ?',
#    'Quelle est la tendance du marché des fruits exotiques en Europe ?',
#    'Quels sont les principaux concurrents sur le marché des céréales en Amérique du Nord ?',
#    "Quelle est la variation des importations de café en Allemagne par rapport à l'année précédente ?",
#    'Quelle est la production de pommes de terre en Chine en 2024 ?',
#    'Quel est le taux de croissance du marché des produits biologiques en Australie ?',
#    'Quelle est la demande prévue pour les noix de cajou en 2025 ?',
#    'Quel est le prix moyen du sucre sur le marché brésilien ?',
#    'Quelle est la répartition des volumes collectés pour les olives en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de vin français par rapport à l'année précédente ?",
#    'Quelle est la production de canne à sucre en Inde en 2024 ?',
#    'Quel est le taux de croissance annuel moyen du marché des fruits de mer depuis 2020 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle des prix du maïs sur le marché mondial ?',
#    'Quels sont les principaux facteurs influençant la demande de soja en 2024 ?',
#    'Comment les conditions météorologiques ont-elles affecté la production de blé en 2023 ?',
#    "Quelles sont les prévisions de production de riz pour l'année 2024 ?",
#    "Quel est l'impact des politiques gouvernementales sur le marché du lait ?",
#    'Quelle est la répartition des exportations de café par région en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché du cacao ?',
#    'Comment la demande de viande bovine a-t-elle évolué au cours des cinq dernières années ?',
#    'Quelle est la variation des importations de fruits tropicaux en Europe en 2024 ?',
#    'Quels sont les défis actuels pour les producteurs de coton ?',
#    'Quelle est la tendance des prix des engrais en 2024 ?',
#    "Quels sont les principaux marchés d'exportation pour les noix de cajou ?",
#    'Comment les innovations technologiques influencent-elles le marché des légumes biologiques ?',
#    'Quelle est la production prévue de pommes de terre en 2024 ?',
#    'Quels sont les facteurs de risque pour les investissements dans le secteur agricole ?',
#    'Quelle est la demande de produits laitiers bio en 2024 ?',
#    'Comment les accords commerciaux internationaux affectent-ils le marché du sucre ?',
#    'Quelle est la situation actuelle du marché des graines oléagineuses ?',
#    "Quels sont les principaux défis logistiques pour l'exportation de produits agricoles ?",
#    'Quelle est la tendance des prix des céréales secondaires en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de soja ?',
#    'Quel est le prix de référence du blé tendre en 2024 ?',
#    "Quelle est la répartition des volumes collectés pour l'orge en 2024 par rapport à la moyenne quinquennale 2018-2023 ?",
#    "Quelle est la variation des exportations de maïs de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quels sont les principaux facteurs influençant le prix du lait en 2024 ?',
#    'Quelle est la tendance du marché pour les pommes de terre en 2024 ?',
#    'Quelle est la demande prévue pour le riz en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché du coton en 2024 ?',
#    'Quelle est la production de tomates en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de betteraves sucrières ?',
#    "Quel est le prix de référence de l'huile d'olive en 2024 ?",
#    'Quelle est la répartition des volumes collectés pour les pois chiches en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de viande bovine de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quels sont les principaux facteurs influençant le prix des œufs en 2024 ?',
#    'Quelle est la tendance du marché pour les avocats en 2024 ?',
#    'Quelle est la demande prévue pour le café en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché du cacao en 2024 ?',
#    'Quelle est la production de bananes en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de noix de coco ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production mondiale de maïs en 2024 ?',
#    'Quel est le prix actuel du soja sur le marché international ?',
#    'Quelles sont les prévisions de demande pour le blé tendre en Europe pour 2025 ?',
#    'Quelle région a enregistré la plus forte baisse de la production de colza ?',
#    "Quel est l'impact des conditions météorologiques sur la production de riz en Asie ?",
#    'Quelle est la part de marché des grands producteurs de lait en France ?',
#    'Quels sont les principaux exportateurs de café en 2024 ?',
#    "Quelle est la variation des importations de viande bovine au Brésil par rapport à l'année précédente ?",
#    'Quels sont les facteurs influençant les prix du sucre sur le marché mondial ?',
#    'Quelle est la production de pommes de terre en Europe en 2024 ?',
#    'Quels sont les défis actuels du marché des produits laitiers en Amérique du Nord ?',
#    'Quelle est la répartition des volumes collectés pour les oléagineux en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    'Quel est le prix de référence du coton en 2024 ?',
#    'Quelle est la tendance actuelle du marché des fruits et légumes en Afrique ?',
#    'Quels sont les principaux importateurs de céréales en 2024 ?',
#    'Quelle est la production de betteraves sucrières en Europe en 2024 ?',
#    'Quels sont les facteurs influençant la demande de produits bio sur le marché européen ?',
#    "Quelle est la variation des exportations de maïs des États-Unis par rapport à l'année précédente ?",
#    'Quels sont les principaux concurrents sur le marché mondial du cacao ?',
#    'Quelle est la production de tomates en Californie en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle des prix du maïs sur le marché mondial ?',
#    'Quels sont les principaux facteurs influençant la demande de soja en 2024 ?',
#    'Comment les politiques commerciales affectent-elles les exportations de riz ?',
#    "Quelle est la prévision de production de blé pour l'année 2025 ?",
#    "Quels sont les principaux concurrents sur le marché de l'huile de palme ?",
#    "Quelle est l'évolution des prix des engrais au cours des derniers mois ?",
#    'Quels sont les défis actuels pour les producteurs de lait ?',
#    'Quelle est la demande prévue pour les légumes biologiques en 2024 ?',
#    'Comment les conditions météorologiques ont-elles impacté la récolte de pommes de terre cette année ?',
#    'Quelle est la part de marché des produits agricoles locaux par rapport aux importations ?',
#    'Quels sont les principaux débouchés pour le sorgho en 2024 ?',
#    "Quelle est la variation des importations de viande bovine par rapport à l'année précédente ?",
#    'Quels sont les coûts de production actuels pour les agriculteurs de betteraves sucrières ?',
#    'Quelle est la situation actuelle du marché des céréales en Europe ?',
#    "Quels sont les principaux défis logistiques pour l'exportation des produits agricoles ?",
#    'Quelle est la demande prévue pour les fruits exotiques en 2024 ?',
#    'Comment les subventions gouvernementales influencent-elles la production de coton ?',
#    "Quelle est l'évolution des prix des produits laitiers au cours des derniers trimestres ?",
#    "Quels sont les principaux marchés d'exportation pour les vins français ?",
#    'Quelle est la tendance actuelle des prix des fruits et légumes sur le marché national ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle des prix du maïs sur le marché mondial ?',
#    'Quelles sont les prévisions de demande pour le riz en 2025 ?',
#    'Comment les politiques commerciales affectent-elles les exportations de soja ?',
#    'Quels sont les principaux défis auxquels sont confrontés les producteurs de lait en Europe ?',
#    "Quelle est l'évolution des importations de café au cours des cinq dernières années ?",
#    'Quels sont les facteurs influençant le prix du blé en France ?',
#    'Quelle est la production de pommes de terre en Amérique du Nord en 2024 ?',
#    'Comment la demande de produits biologiques a-t-elle évolué ces dernières années ?',
#    'Quels sont les principaux concurrents sur le marché du coton ?',
#    'Quelle est la répartition des volumes de production de tomates en 2024 ?',
#    'Quels sont les impacts de la météo sur la production de vin en 2024 ?',
#    "Quelle est la variation des exportations de fruits tropicaux par rapport à l'année précédente ?",
#    'Quels sont les prix de référence pour le bœuf et le porc en 2024 ?',
#    'Quelle région a enregistré la plus forte baisse de la production de céréales ?',
#    "Quels sont les principaux marchés d'exportation pour les produits laitiers ?",
#    'Quelle est la tendance des prix des engrais en 2024 ?',
#    'Quels sont les facteurs influençant la demande de miel en Europe ?',
#    'Quelle est la production de légumes en serre en 2024 ?',
#    'Comment les subventions agricoles affectent-elles la production de céréales ?',
#    'Quels sont les principaux défis pour les producteurs de fruits en Amérique du Sud ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte baisse de la collecte de colza ?',
#    'Quel est le prix de référence du lait en 2024 ?',
#    'Quelle est la répartition des volumes collectés pour les pommes de terre en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des importations de soja de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quels sont les principaux facteurs influençant les prix des céréales en 2024 ?',
#    'Quelle est la demande prévue pour le riz en 2024 ?',
#    'Quelle est la tendance du marché pour les agrumes en 2024 ?',
#    'Quelle est la part de marché des producteurs de betteraves sucrières en 2024 ?',
#    "Quelle est l'évolution des prix des engrais en 2024 par rapport à 2023 ?",
#    'Quels sont les défis majeurs pour les producteurs de légumes en 2024 ?',
#    'Quelle est la situation du marché des viandes bovines en 2024 ?',
#    'Quelle est la production de vin en 2024 et comment se compare-t-elle à 2023 ?',
#    'Quelle est la demande mondiale pour les produits laitiers en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché des oléagineux en 2024 ?',
#    'Quelle est la tendance des prix des fruits et légumes bio en 2024 ?',
#    'Quelle est la production de coton en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle est la situation du marché des produits avicoles en 2024 ?',
#    'Quelle est la demande prévue pour les produits de la pêche en 2024 ?',
#    'Quelle est la tendance du marché des produits apicoles en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quels sont les principaux facteurs influençant les prix du maïs en 2024 ?',
#    'Quelle est la demande prévue pour les produits laitiers au cours des deux prochaines années ?',
#    'Comment les politiques commerciales affectent-elles les exportations de riz en Asie ?',
#    'Quelle est la tendance actuelle des prix des engrais sur le marché mondial ?',
#    'Quels sont les défis majeurs auxquels sont confrontés les producteurs de soja en Amérique du Sud ?',
#    'Quelle est la répartition des volumes collectés pour les pommes de terre en 2024 par rapport à 2023 ?',
#    "Quelle est l'évolution des importations de café en Europe depuis 2020 ?",
#    'Quels sont les principaux concurrents sur le marché du blé en Russie ?',
#    'Quelle est la variation des prix du coton en Inde au cours des derniers mois ?',
#    'Quelle est la production de viande bovine en Australie en 2024 ?',
#    'Quels sont les facteurs qui influencent la demande de légumes biologiques en France ?',
#    'Quelle est la tendance actuelle des prix du sucre sur le marché brésilien ?',
#    'Quelle est la répartition des volumes collectés pour les olives en Espagne en 2024 ?',
#    "Quelle est l'évolution des exportations de vin français vers les États-Unis depuis 2021 ?",
#    "Quels sont les défis majeurs pour les producteurs de cacao en Afrique de l'Ouest ?",
#    'Quelle est la demande prévue pour les produits avicoles en Chine en 2025 ?',
#    'Comment les conditions météorologiques affectent-elles la production de blé en Ukraine ?',
#    'Quelle est la tendance actuelle des prix du riz sur le marché indien ?',
#    'Quelle est la répartition des volumes collectés pour les tomates en Italie en 2024 ?',
#    "Quelle est l'évolution des importations de fruits tropicaux en Europe depuis 2022 ?"],
#   'theme': 'market_question'},
#  {'questions': ['Quel est le prix actuel du maïs sur le marché européen ?',
#    'Quelles sont les prévisions de demande pour le soja en 2025 ?',
#    'Quelle est la tendance des prix du blé au cours des cinq dernières années ?',
#    'Quels sont les principaux exportateurs de riz en 2024 ?',
#    'Quelle est la production mondiale de café en 2024 ?',
#    'Quels sont les facteurs influençant le prix du coton ?',
#    'Quelle est la répartition des volumes de vente de pommes de terre en Europe ?',
#    "Quelle est la variation des importations de sucre en Inde par rapport à l'année précédente ?",
#    'Quels sont les principaux concurrents sur le marché du lait en poudre ?',
#    'Quelle est la production de tomates en Espagne en 2024 ?',
#    'Quelle est la tendance des prix des agrumes en Amérique du Sud ?',
#    'Quelle est la demande de viande bovine en Chine en 2024 ?',
#    'Quels sont les principaux producteurs de soja en Amérique du Nord ?',
#    'Quelle est la production de maïs en France en 2024 ?',
#    'Quelle est la tendance des prix du riz basmati en Inde ?',
#    'Quelle est la demande de blé dur en Italie en 2024 ?',
#    'Quels sont les principaux importateurs de café au Brésil ?',
#    'Quelle est la production de pommes en Pologne en 2024 ?',
#    'Quelle est la tendance des prix du lait en France ?',
#    'Quelle est la demande de sucre en Russie en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de soja ?',
#    'Quel est le prix de référence du riz ?',
#    'Quelle est la répartition des volumes collectés pour les pommes de terre en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de blé dur de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quelle est la demande prévue pour le lait en 2025 ?',
#    'Quels sont les principaux concurrents sur le marché du café ?',
#    'Quelle est la tendance actuelle des prix du coton ?',
#    'Quelle région a enregistré la plus forte baisse de la collecte de betteraves à sucre ?',
#    "Quel est le prix de référence de l'huile d'olive ?",
#    'Quelle est la production de tomates en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle est la répartition des volumes collectés pour les carottes en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des importations de pommes de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quelle est la demande prévue pour le vin en 2025 ?',
#    'Quels sont les principaux concurrents sur le marché du fromage ?',
#    'Quelle est la tendance actuelle des prix du porc ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de pois chiches ?',
#    'Quel est le prix de référence de la viande bovine ?',
#    'Quelle est la production de poivrons en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle est la répartition des volumes collectés pour les courgettes en 2024 par rapport à la moyenne quinquennale 2018-2023 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de soja ?',
#    'Quel est le prix de référence du blé dur ?',
#    'Quelle est la répartition des volumes collectés pour les pois chiches en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de maïs de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quelle est la demande prévue pour les pommes de terre en 2024 ?',
#    'Quels sont les principaux importateurs de riz en 2024 ?',
#    'Quelle est la tendance des prix du lait sur le marché européen en 2024 ?',
#    'Quelle est la production de viande bovine en 2024 comparée à 2023 ?',
#    'Quelle région a enregistré la plus forte baisse de la collecte de betteraves sucrières ?',
#    "Quel est le prix de référence de l'huile d'olive ?",
#    'Quelle est la répartition des volumes collectés pour les lentilles en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des importations de café de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quelle est la demande prévue pour les avocats en 2024 ?',
#    'Quels sont les principaux exportateurs de cacao en 2024 ?',
#    'Quelle est la tendance des prix des œufs sur le marché américain en 2024 ?',
#    'Quelle est la production de pommes en 2024 comparée à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de noix ?',
#    'Quel est le prix de référence du coton ?',
#    'Quelle est la répartition des volumes collectés pour les haricots en 2024 par rapport à la moyenne quinquennale 2018-2023 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 par rapport à 2023 ?',
#    'Quel est le prix moyen du blé en France en 2024 ?',
#    'Quelle région a enregistré la plus forte baisse de la collecte de colza ?',
#    'Quelle est la demande prévue pour les pommes de terre en 2025 ?',
#    'Quel est le prix de référence du lait en Europe en 2024 ?',
#    'Quelle est la répartition des volumes collectés pour les pois chiches en 2024 ?',
#    "Quelle est la variation des importations de soja en France par rapport à l'année précédente ?",
#    "Quel est l'impact des conditions météorologiques sur la production de riz en 2024 ?",
#    'Quelle est la tendance des prix des engrais en 2024 ?',
#    'Quelle est la part de marché des producteurs de betteraves sucrières en Europe ?',
#    'Quelle est la demande mondiale pour le cacao en 2024 ?',
#    "Quel est le prix moyen de l'orge en 2024 ?",
#    'Quelle est la production de pommes en France en 2024 ?',
#    "Quelle est la variation des exportations de vin français par rapport à l'année précédente ?",
#    'Quel est le prix de référence du coton en 2024 ?',
#    'Quelle est la répartition des volumes collectés pour les lentilles en 2024 ?',
#    'Quelle est la demande prévue pour les carottes en 2025 ?',
#    "Quel est l'impact des politiques agricoles sur le marché du maïs en 2024 ?",
#    'Quelle est la tendance des prix des semences en 2024 ?',
#    'Quelle est la part de marché des producteurs de tomates en Espagne ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte baisse de la collecte de colza ?',
#    'Quel est le prix de référence du lait ?',
#    'Quelle est la répartition des volumes collectés pour les pois chiches en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des importations de soja de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quels sont les principaux facteurs influençant les prix du blé en 2024 ?',
#    'Quelle est la demande prévue pour les pommes de terre en 2024 ?',
#    'Quelle est la part de marché des producteurs locaux de légumes en France ?',
#    'Quelle est la tendance du marché des fruits exotiques en Europe ?',
#    "Quel est l'impact des politiques agricoles sur les prix des céréales en 2024 ?",
#    'Quelle est la production de viande bovine en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la production de miel ?',
#    'Quel est le prix de référence du coton ?',
#    'Quelle est la répartition des volumes collectés pour les olives en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de riz de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quels sont les principaux défis pour les producteurs de lait en 2024 ?',
#    'Quelle est la demande prévue pour les avocats en 2024 ?',
#    'Quelle est la part de marché des producteurs bio de fruits en Allemagne ?',
#    'Quelle est la tendance du marché des épices en Asie ?',
#    "Quel est l'impact des conditions climatiques sur les prix des légumes en 2024 ?"],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle des prix du maïs sur le marché mondial ?',
#    'Quels sont les principaux facteurs influençant les prix des produits agricoles en 2024 ?',
#    'Quelle est la demande prévue pour les oléagineux en 2025 ?',
#    'Comment les politiques commerciales affectent-elles le marché des céréales ?',
#    'Quelle est la production mondiale de soja en 2024 ?',
#    'Quels sont les défis actuels pour les producteurs de lait en Europe ?',
#    'Quelle est la répartition des exportations de riz par région en 2024 ?',
#    "Quel est l'impact des conditions météorologiques sur les prix des fruits et légumes ?",
#    'Quelle est la demande de viande bovine en Amérique du Nord en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché du café ?',
#    'Quelle est la production de blé en Russie en 2024 ?',
#    'Quels sont les facteurs influençant la demande de produits biologiques ?',
#    'Quelle est la tendance des prix des engrais en 2024 ?',
#    'Quels sont les principaux défis pour les exportateurs de fruits en Asie ?',
#    'Quelle est la demande de produits laitiers en Afrique en 2024 ?',
#    'Quels sont les principaux importateurs de maïs en 2024 ?',
#    'Quelle est la production de pommes de terre en Europe en 2024 ?',
#    'Quels sont les facteurs influençant les prix du cacao ?',
#    'Quelle est la demande de produits avicoles en Amérique du Sud en 2024 ?',
#    'Quels sont les principaux défis pour les producteurs de coton en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de colza ?',
#    'Quel est le prix de référence du blé tendre en 2024 ?',
#    'Quelle est la répartition des volumes collectés pour les pois chiches en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de soja de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quelle est la tendance des prix du lait sur le marché européen en 2024 ?',
#    'Quelle est la demande prévue pour les pommes de terre en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché du riz en 2024 ?',
#    'Quelle est la production de viande bovine en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de betteraves sucrières ?',
#    "Quel est le prix de référence de l'huile d'olive en 2024 ?",
#    'Quelle est la répartition des volumes collectés pour les lentilles en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de pommes de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quelle est la tendance des prix du café sur le marché mondial en 2024 ?',
#    'Quelle est la demande prévue pour les avocats en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché du cacao en 2024 ?',
#    'Quelle est la production de lait en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de noix ?',
#    'Quel est le prix de référence du coton en 2024 ?',
#    'Quelle est la répartition des volumes collectés pour les haricots en 2024 par rapport à la moyenne quinquennale 2018-2023 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production mondiale de maïs en 2024 ?',
#    'Quel est le prix moyen du soja en 2024 par rapport à 2023 ?',
#    'Quelle région a vu la plus grande baisse de la production de blé en 2024 ?',
#    'Quelle est la demande prévue pour les pommes de terre en 2025 ?',
#    "Quel est l'impact des conditions météorologiques sur la production de riz en 2024 ?",
#    'Quelle est la part de marché des principaux producteurs de lait en 2024 ?',
#    'Quelle est la tendance des prix du coton au cours des derniers mois ?',
#    'Quelle est la production de café en Amérique du Sud en 2024 ?',
#    'Quel est le taux de croissance de la production de viande bovine en 2024 ?',
#    'Quelle est la répartition des exportations de fruits et légumes en 2024 ?',
#    'Quel est le prix de référence du cacao en 2024 ?',
#    'Quelle est la production de sucre de betterave en Europe en 2024 ?',
#    'Quelle est la demande mondiale de produits laitiers en 2024 ?',
#    "Quel est l'impact des politiques agricoles sur les prix du maïs en 2024 ?",
#    'Quelle est la production de tomates en Espagne en 2024 ?',
#    'Quel est le taux de croissance de la production de vin en France en 2024 ?',
#    'Quelle est la répartition des importations de produits agricoles en 2024 ?',
#    'Quel est le prix moyen de la viande de porc en 2024 ?',
#    'Quelle est la production de pommes en France en 2024 ?',
#    "Quel est l'impact des technologies agricoles sur la production de blé en 2024 ?"],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle des prix du maïs sur le marché mondial ?',
#    'Comment les politiques commerciales affectent-elles les exportations de soja ?',
#    'Quelles sont les prévisions de demande pour le riz en 2024 ?',
#    "Quel est l'impact des conditions météorologiques sur la production de blé cette année ?",
#    'Quels sont les principaux défis auxquels sont confrontés les producteurs de lait en Europe ?',
#    'Quelle est la répartition des volumes collectés pour les pommes de terre en 2024 par rapport à 2023 ?',
#    'Quels pays sont les plus grands importateurs de café ?',
#    "Quelle est la variation des importations de viande bovine en Chine par rapport à l'année précédente ?",
#    'Quels sont les facteurs influençant les prix du coton sur le marché international ?',
#    'Quelle est la production de canne à sucre en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de colza ?',
#    'Quel est le prix de référence du cacao ?',
#    'Quelle est la répartition des volumes collectés pour les olives en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de maïs des États-Unis par rapport à l'année précédente ?",
#    'Quels sont les principaux concurrents sur le marché du riz basmati ?',
#    'Quelle est la tendance actuelle des prix du café arabica ?',
#    'Comment les innovations technologiques affectent-elles la production de tomates ?',
#    'Quelles sont les prévisions de demande pour le blé dur en 2024 ?',
#    "Quel est l'impact des subventions agricoles sur les prix des produits laitiers ?",
#    "Quelle est la variation des importations de fruits tropicaux en Europe par rapport à l'année précédente ?"],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle des prix du maïs sur le marché mondial ?',
#    'Quelles sont les prévisions de demande pour le soja en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché du riz en Asie ?',
#    'Comment les prix du blé ont-ils évolué au cours des cinq dernières années ?',
#    "Quelle est la production de coton en Inde pour l'année 2024 ?",
#    'Quels sont les facteurs influençant les prix du café sur le marché international ?',
#    'Quelle région a enregistré la plus forte baisse de la production de pommes de terre ?',
#    'Quel est le prix de référence du lait en Europe ?',
#    'Quelle est la répartition des volumes exportés de maïs par les États-Unis en 2024 ?',
#    "Quelle est la variation des importations de riz en Chine par rapport à l'année précédente ?",
#    'Quels sont les principaux défis du marché du cacao en Afrique ?',
#    "Quelle est la production de tomates en Espagne pour l'année 2024 ?",
#    'Quels sont les facteurs influençant les prix du sucre sur le marché brésilien ?',
#    'Quelle est la tendance des prix du porc en Chine au cours des six derniers mois ?',
#    "Quelle est la production de vin en France pour l'année 2024 ?",
#    'Quels sont les principaux exportateurs de blé tendre en Europe ?',
#    'Quelle est la demande prévue pour le coton en 2025 ?',
#    'Quels sont les principaux importateurs de café en Amérique du Nord ?',
#    "Quelle est la production de canne à sucre au Brésil pour l'année 2024 ?",
#    'Quels sont les facteurs influençant les prix du maïs sur le marché argentin ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de soja ?',
#    'Quel est le prix de référence du blé tendre en 2024 ?',
#    'Quelle est la répartition des volumes collectés pour le colza en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des importations de riz de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quels sont les principaux facteurs influençant le prix du lait en 2024 ?',
#    'Quelle est la demande prévue pour les pommes de terre en 2024 ?',
#    'Quels sont les principaux concurrents sur le marché du café en 2024 ?',
#    'Quelle est la tendance du marché des agrumes en 2024 ?',
#    "Quel est l'impact des conditions météorologiques sur la production de céréales en 2024 ?",
#    'Quelle est la part de marché des produits biologiques en 2024 ?',
#    'Quels sont les défis majeurs pour les producteurs de viande bovine en 2024 ?',
#    'Quelle est la consommation de légumes frais en 2024 par rapport à 2023 ?',
#    'Quels sont les principaux exportateurs de fruits tropicaux en 2024 ?',
#    'Quelle est la situation du marché des oléagineux en 2024 ?',
#    'Quel est le prix moyen du coton en 2024 ?',
#    'Quelle est la production de vin en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quels sont les principaux débouchés pour le maïs en 2024 ?',
#    'Quelle est la demande prévue pour les produits laitiers en 2024 ?',
#    'Quels sont les principaux défis pour les producteurs de cacao en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle du marché du maïs en Europe ?',
#    'Quel est le prix moyen du blé en France en 2024 ?',
#    'Quelles sont les prévisions de demande pour les pommes de terre en 2025 ?',
#    'Quelle région a connu la plus forte baisse de la production de soja cette année ?',
#    "Quel est l'impact des conditions météorologiques sur les prix des céréales en 2024 ?",
#    'Quelle est la part de marché des producteurs de lait bio en Allemagne ?',
#    'Quels sont les principaux exportateurs de riz en Asie en 2024 ?',
#    "Quelle est la variation des importations de viande bovine en Chine par rapport à l'année précédente ?",
#    "Quel est le coût de production moyen de l'huile d'olive en Italie ?",
#    'Quelles sont les prévisions de rendement pour le coton en Inde en 2024 ?',
#    'Quelle est la répartition des volumes de vente de tomates en Espagne par rapport à la moyenne des cinq dernières années ?',
#    'Quel est le prix de référence du café arabica sur le marché mondial ?',
#    'Quelle région a enregistré la plus forte augmentation de la production de betteraves sucrières ?',
#    'Quels sont les principaux concurrents sur le marché des agrumes en Amérique du Sud ?',
#    'Quelle est la tendance des prix des légumes bio en France en 2024 ?',
#    "Quelle est la variation des exportations de vin français par rapport à l'année précédente ?",
#    "Quel est l'impact des politiques agricoles de l'UE sur les prix des produits laitiers ?",
#    'Quelles sont les prévisions de demande pour les fruits tropicaux en 2025 ?',
#    'Quelle est la répartition des volumes collectés pour les oléagineux en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    'Quel est le prix moyen du porc en Chine en 2024 ?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la tendance actuelle des prix du maïs sur le marché mondial?',
#    'Quels sont les principaux facteurs influençant la demande de soja en 2024?',
#    'Comment les politiques commerciales affectent-elles les exportations de riz?',
#    "Quelle est la prévision de production de blé pour l'année 2025?",
#    'Quels pays sont les plus grands importateurs de café?',
#    'Quelle est la variation des prix du coton au cours des trois derniers mois?',
#    'Quels sont les défis actuels du marché des produits laitiers?',
#    "Quelle est l'évolution des prix des engrais depuis le début de l'année?",
#    'Quels sont les principaux concurrents sur le marché des agrumes?',
#    'Quelle est la demande prévue pour les légumes biologiques en 2024?',
#    'Comment les conditions météorologiques affectent-elles la production de pommes de terre?',
#    'Quelle est la part de marché des produits agricoles locaux par rapport aux importations?',
#    'Quels sont les nouveaux marchés émergents pour les exportations de fruits?',
#    'Quelle est la situation actuelle des stocks de céréales dans le monde?',
#    'Quels sont les impacts des subventions agricoles sur les prix des produits?',
#    'Quelle est la tendance des prix des viandes bovines et porcines?',
#    "Quels sont les principaux défis logistiques pour l'exportation des produits agricoles?",
#    'Quelle est la demande prévue pour les produits agricoles transformés en 2025?',
#    'Comment les innovations technologiques influencent-elles le marché agricole?',
#    'Quelle est la situation actuelle des prix des produits de la pêche?'],
#   'theme': 'market_question'},
#  {'questions': ['Quelle est la production de maïs en 2024 et comment a-t-elle évolué par rapport à 2023 ?',
#    'Quelle région a enregistré la plus forte augmentation de la collecte de soja ?',
#    'Quel est le prix de référence du lait en 2024 ?',
#    'Quelle est la répartition des volumes collectés pour les pommes de terre en 2024 par rapport à la moyenne quinquennale 2018-2023 ?',
#    "Quelle est la variation des exportations de riz de l'UE par rapport à l'année précédente au 3 mars 2024 ?",
#    'Quels sont les principaux défis du marché de la viande bovine en 2024 ?',
#    'Quelle est la demande prévue pour les fruits et légumes bio en 2025 ?',
# ...
#    "Comment évaluer et améliorer la résilience climatique d'une exploitation agricole ?"],
#   'theme': 'other'},
#  {'questions': ["Quels sont les avantages et les inconvénients de l'agriculture biologique ?",
#    "Comment optimiser l'utilisation de l'eau dans une exploitation agricole ?",
#    'Quelles sont les meilleures pratiques pour la gestion des sols en agriculture ?',
#    'Comment lutter contre les ravageurs et les maladies des cultures de manière écologique ?',
#    "Quels sont les impacts environnementaux de l'agriculture intensive ?",
#    "Comment diversifier les cultures pour améliorer la résilience de l'exploitation ?",
#    'Quelles sont les alternatives aux pesticides chimiques ?',
#    "Comment intégrer l'agroforesterie dans une exploitation agricole ?",
#    "Quels sont les bénéfices de l'agriculture urbaine ?",
#    'Comment améliorer la biodiversité sur une exploitation agricole ?',
#    'Quelles sont les techniques de conservation des sols les plus efficaces ?',
#    'Comment utiliser les données météorologiques pour optimiser les pratiques agricoles ?',
#    "Quels sont les défis et les opportunités de l'agriculture verticale ?",
#    'Comment gérer les déchets agricoles de manière durable ?',
#    'Quelles sont les innovations récentes en matière de semences et de variétés de cultures ?',
#    'Comment intégrer les énergies renouvelables dans une exploitation agricole ?',
#    'Quelles sont les meilleures pratiques pour la gestion des ressources en eau en agriculture ?',
#    'Comment améliorer la santé des sols grâce à la rotation des cultures ?',
#    "Quels sont les avantages et les inconvénients de l'agriculture contractuelle ?",
#    'Comment utiliser les drones pour améliorer la gestion des cultures ?'],
#   'theme': 'other'},
#  {'questions': ['Quels sont les avantages des cultures de couverture ?',
#    "Comment optimiser l'irrigation pour économiser l'eau ?",
#    'Quelles sont les meilleures pratiques pour la gestion des sols ?',
#    'Comment lutter contre les ravageurs de manière biologique ?',
#    "Quels sont les impacts des changements climatiques sur l'agriculture ?",
#    'Comment améliorer la fertilité des sols naturellement ?',
#    'Quelles sont les techniques de rotation des cultures ?',
#    'Comment gérer les maladies des plantes de manière préventive ?',
#    "Quels sont les bénéfices de l'agroforesterie ?",
#    'Comment utiliser les drones pour surveiller les cultures ?',
#    'Quelles sont les méthodes de conservation des sols ?',
#    "Comment intégrer l'agriculture urbaine dans les villes ?",
#    "Quels sont les avantages de l'agriculture biologique ?",
#    'Comment gérer les ressources en eau en agriculture ?',
#    'Quelles sont les techniques de compostage efficaces ?',
#    'Comment utiliser les capteurs pour monitorer les sols ?',
#    "Quels sont les défis de l'agriculture durable ?",
#    'Comment améliorer la biodiversité dans les champs ?',
#    'Quelles sont les méthodes de lutte intégrée contre les ravageurs ?',
#    "Comment utiliser les technologies GPS pour l'agriculture de précision ?"],
#   'theme': 'other'},
#  {'questions': ["Quelles sont les meilleures pratiques pour la gestion de l'eau en agriculture ?",
#    'Comment choisir les semences les plus adaptées à mon type de sol ?',
#    "Quels sont les avantages et inconvénients de l'agriculture biologique ?",
#    'Comment gérer les maladies et les parasites des cultures de manière naturelle ?',
#    'Quelles sont les techniques de rotation des cultures les plus efficaces ?',
#    'Comment utiliser les drones pour surveiller les cultures ?',
#    'Quels sont les défis liés à la gestion des déchets agricoles ?',
#    'Comment améliorer la fertilité du sol de manière durable ?',
#    'Quelles sont les méthodes de stockage des récoltes pour éviter les pertes ?',
#    'Comment établir un calendrier de plantation optimal ?',
#    "Quels sont les impacts des changements climatiques sur l'agriculture locale ?",
#    'Comment intégrer les pratiques agroforestières dans une exploitation agricole ?',
#    'Quelles sont les alternatives aux pesticides chimiques ?',
#    "Comment utiliser les capteurs pour optimiser l'irrigation ?",
#    'Quels sont les avantages de la diversification des cultures ?',
#    'Comment gérer les sols dégradés pour les rendre à nouveau productifs ?',
#    'Quelles sont les techniques de conservation des sols les plus efficaces ?',
#    'Comment utiliser les données météorologiques pour planifier les activités agricoles ?',
#    "Quels sont les défis et opportunités de l'agriculture urbaine ?",
#    'Comment évaluer la qualité des produits agricoles avant la vente ?'],
#   'theme': 'other'},
#  {'questions': ["Quels sont les avantages et les inconvénients de l'utilisation de drones en agriculture ?",
#    "Comment optimiser l'irrigation pour économiser l'eau et améliorer les rendements ?",
#    'Quelles sont les meilleures pratiques pour la rotation des cultures ?',
#    'Comment gérer efficacement les parasites et les maladies dans une exploitation agricole ?',
#    "Quels sont les bénéfices de l'agriculture biologique par rapport à l'agriculture conventionnelle ?",
#    'Comment intégrer les énergies renouvelables dans une exploitation agricole ?',
#    'Quelles sont les méthodes pour améliorer la santé des sols ?',
#    'Comment utiliser les données météorologiques pour planifier les activités agricoles ?',
#    'Quels sont les défis et les solutions pour la gestion des déchets agricoles ?',
#    'Comment améliorer la biodiversité dans une exploitation agricole ?',
#    "Quelles sont les techniques de conservation de l'eau en agriculture ?",
#    'Comment évaluer la qualité du sol avant de planter une nouvelle culture ?',
#    "Quels sont les avantages de l'agroforesterie ?",
#    'Comment gérer les ressources en eau de manière durable ?',
#    'Quelles sont les innovations récentes en matière de fertilisation ?',
#    "Comment utiliser les technologies de l'information pour améliorer la gestion agricole ?",
#    "Quels sont les impacts de la digitalisation sur l'agriculture ?",
#    "Comment évaluer l'impact environnemental d'une exploitation agricole ?",
#    'Quelles sont les stratégies pour atténuer les effets du changement climatique en agriculture ?',
#    'Comment utiliser les biotechnologies pour améliorer les rendements agricoles ?'],
#   'theme': 'other'},
#  {'questions': ['Quels sont les avantages et inconvénients des cultures hors-sol ?',
#    "Comment optimiser l'irrigation pour économiser l'eau dans les cultures ?",
#    'Quelles sont les meilleures pratiques pour la gestion des sols en agriculture biologique ?',
#    'Comment lutter contre les ravageurs de manière écologique ?',
#    'Quels sont les critères pour choisir une semence adaptée à mon sol ?',
#    'Comment améliorer la biodiversité sur une exploitation agricole ?',
#    'Quelles sont les techniques de conservation des aliments récoltés ?',
#    'Comment gérer efficacement les déchets agricoles ?',
#    "Quels sont les impacts du changement climatique sur l'agriculture locale ?",
#    "Comment intégrer l'agroforesterie dans une exploitation agricole ?",
#    "Quelles sont les solutions pour limiter l'érosion des sols ?",
#    'Comment utiliser les drones pour surveiller les cultures ?',
#    'Quels sont les avantages de la rotation des cultures ?',
#    'Comment gérer les maladies des plantes de manière préventive ?',
#    'Quelles sont les méthodes pour améliorer la fertilité du sol ?',
#    'Comment mettre en place un système de compostage efficace ?',
#    "Quels sont les défis de l'agriculture urbaine ?",
#    'Comment utiliser les capteurs pour monitorer la santé des plantes ?',
#    "Quelles sont les techniques pour conserver l'eau de pluie en agriculture ?",
#    'Comment évaluer la qualité des sols avant de planter ?'],
#   'theme': 'other'},
#  {'questions': ["Quels sont les avantages et inconvénients de l'agriculture biologique ?",
#    "Comment optimiser l'irrigation pour économiser l'eau dans une exploitation agricole ?",
#    'Quelles sont les meilleures pratiques pour la gestion des sols en agriculture durable ?',
#    'Comment choisir les bonnes semences pour maximiser le rendement des cultures ?',
#    "Quels sont les défis et opportunités de l'agriculture urbaine ?",
#    'Comment gérer efficacement les déchets agricoles ?',
#    'Quelles sont les méthodes pour contrôler les mauvaises herbes sans utiliser de pesticides ?',
#    "Comment intégrer l'apiculture dans une exploitation agricole diversifiée ?",
#    "Quels sont les impacts du changement climatique sur l'agriculture et comment s'y adapter ?",
#    'Comment améliorer la biodiversité sur une exploitation agricole ?',
#    'Quelles sont les techniques de conservation des sols les plus efficaces ?',
#    'Comment utiliser les drones pour surveiller les cultures et optimiser les rendements ?',
#    'Quels sont les avantages de la rotation des cultures ?',
#    'Comment gérer les parasites et maladies des cultures de manière biologique ?',
#    'Quelles sont les opportunités de diversification des revenus pour les agriculteurs ?',
#    'Comment mettre en place un système de compostage efficace sur une exploitation agricole ?',
#    "Quels sont les avantages de l'agroforesterie pour l'agriculture ?",
#    'Comment utiliser les capteurs pour monitorer les conditions du sol et des plantes ?',
#    "Quelles sont les meilleures pratiques pour la gestion de l'eau dans les zones arides ?",
#    "Comment promouvoir l'agriculture locale et les circuits courts ?"],
#   'theme': 'other'},
#  {'questions': ['Quelles sont les meilleures pratiques pour la rotation des cultures ?',
#    "Comment gérer efficacement l'irrigation dans une exploitation agricole ?",
#    "Quels sont les avantages et inconvénients de l'agriculture biologique ?",
#    "Comment optimiser l'utilisation des engrais pour maximiser le rendement ?",
#    'Quelles sont les méthodes de lutte contre les ravageurs sans utiliser de pesticides ?',
#    'Comment améliorer la santé du sol dans une ferme ?',
#    "Quels sont les défis liés à l'agriculture urbaine ?",
#    'Comment choisir les semences les plus adaptées à mon type de sol ?',
#    'Quelles sont les techniques de conservation des sols les plus efficaces ?',
#    "Comment intégrer l'agroforesterie dans une exploitation agricole ?",
#    "Quels sont les avantages de l'agriculture de conservation ?",
#    'Comment gérer les maladies des plantes de manière naturelle ?',
#    "Quelles sont les technologies de l'information utilisées en agriculture ?",
#    "Comment évaluer la qualité de l'eau pour l'irrigation ?",
#    "Quels sont les impacts de l'agriculture intensive sur l'environnement ?",
#    'Comment utiliser les drones pour améliorer la gestion des cultures ?',
#    'Quelles sont les meilleures pratiques pour la gestion des déchets agricoles ?',
#    'Comment intégrer les énergies renouvelables dans une exploitation agricole ?',
#    "Quels sont les défis liés à la gestion de l'eau en agriculture ?",
#    'Comment améliorer la biodiversité sur une exploitation agricole ?'],
#   'theme': 'other'},
#  {'questions': ["Quels sont les avantages et inconvénients de l'agriculture biologique par rapport à l'agriculture conventionnelle ?",
#    "Comment optimiser l'irrigation pour réduire la consommation d'eau en agriculture ?",
#    'Quelles sont les meilleures pratiques pour la gestion des sols en agriculture ?',
#    'Comment lutter contre les ravageurs et les maladies des cultures de manière naturelle ?',
#    "Quels sont les impacts environnementaux de l'agriculture intensive ?",
#    'Comment intégrer les énergies renouvelables dans une exploitation agricole ?',
#    'Quelles sont les techniques de rotation des cultures pour améliorer la fertilité des sols ?',
#    'Comment utiliser les drones pour surveiller les cultures et améliorer la gestion des récoltes ?',
#    'Quelles sont les méthodes de conservation des aliments pour réduire le gaspillage alimentaire ?',
#    'Comment mettre en place un système de compostage efficace sur une exploitation agricole ?',
#    "Quels sont les défis et opportunités de l'agriculture urbaine ?",
#    'Comment gérer les déchets agricoles de manière durable ?',
#    'Quelles sont les stratégies pour diversifier les sources de revenus dans une exploitation agricole ?',
#    "Comment utiliser les capteurs et l'Internet des objets (IoT) pour améliorer la gestion des cultures ?",
#    "Quels sont les avantages de l'agroforesterie pour la biodiversité et la productivité agricole ?",
#    'Comment évaluer la qualité des sols agricoles ?',
#    "Quelles sont les techniques de gestion de l'eau pour prévenir l'érosion des sols ?",
#    'Comment intégrer les pratiques agroécologiques dans une exploitation agricole conventionnelle ?',
#    "Quels sont les impacts du changement climatique sur l'agriculture et comment s'y adapter ?",
#    'Comment améliorer la gestion des ressources humaines dans une exploitation agricole ?'],
#   'theme': 'other'},
#  {'questions': ["Quels sont les avantages de l'agroforesterie en agriculture ?",
#    "Comment gérer efficacement l'irrigation dans une exploitation agricole ?",
#    'Quelles sont les meilleures pratiques pour la rotation des cultures ?',
#    'Comment lutter contre les ravageurs de manière biologique ?',
#    "Quels sont les impacts des changements climatiques sur l'agriculture ?",
#    'Comment améliorer la fertilité du sol de manière durable ?',
#    'Quelles sont les méthodes de conservation des sols en agriculture ?',
#    "Comment optimiser l'utilisation des engrais organiques ?",
#    "Quels sont les défis de la gestion de l'eau en agriculture ?",
#    'Comment intégrer les énergies renouvelables dans une exploitation agricole ?',
#    'Quelles sont les techniques de stockage des récoltes pour minimiser les pertes ?',
#    'Comment utiliser les drones pour surveiller les cultures ?',
#    "Quels sont les avantages de l'agriculture biologique par rapport à l'agriculture conventionnelle ?",
#    'Comment gérer les ressources en eau de manière durable en agriculture ?',
#    'Quelles sont les stratégies pour améliorer la biodiversité dans les exploitations agricoles ?',
#    "Comment utiliser les technologies de l'information pour optimiser la production agricole ?",
#    "Quels sont les avantages et inconvénients de l'agriculture intensive ?",
#    'Comment gérer les déchets agricoles de manière écologique ?',
#    'Quelles sont les méthodes de lutte intégrée contre les maladies des plantes ?',
#    "Comment évaluer la durabilité d'une exploitation agricole ?"],
#   'theme': 'other'},
#  {'questions': ["Quels sont les avantages de l'agriculture biologique par rapport à l'agriculture conventionnelle ?",
#    'Comment gérer efficacement les ressources en eau dans une exploitation agricole ?',
#    'Quelles sont les meilleures pratiques pour la rotation des cultures ?',
#    'Comment lutter contre les parasites et les maladies des cultures de manière écologique ?',
#    "Quels sont les défis et les solutions pour l'agriculture urbaine ?",
#    'Comment améliorer la fertilité du sol de manière naturelle ?',
#    'Quelles sont les techniques de conservation des sols en agriculture ?',
#    "Comment intégrer l'apiculture dans une exploitation agricole ?",
#    "Quels sont les avantages et les inconvénients de l'agriculture hydroponique ?",
#    'Comment évaluer la qualité du sol avant de planter une nouvelle culture ?',
#    'Quelles sont les méthodes de gestion des déchets agricoles ?',
#    'Comment utiliser les drones pour améliorer la gestion des cultures ?',
#    'Quels sont les critères à considérer pour choisir une nouvelle culture à introduire dans une exploitation ?',
#    "Comment optimiser l'utilisation des engrais et des pesticides ?",
#    'Quelles sont les techniques de stockage des récoltes pour éviter les pertes ?',
#    'Comment gérer les risques climatiques en agriculture ?',
#    "Quels sont les avantages de l'agroforesterie ?",
#    'Comment mettre en place un système de compostage efficace sur une exploitation agricole ?',
#    'Quelles sont les innovations récentes en matière de machinerie agricole ?',
#    "Comment évaluer l'impact environnemental de son exploitation agricole ?"],
#   'theme': 'other'}]

# %% [markdown]
# # Evaluate base model

# %%
import pandas as pd

# Flatten q_theme_df: each question gets its own row with the corresponding theme
rows = []
for item in q_theme_df:
    for question in item['questions']:
        rows.append({'question': question, 'theme': item['theme']})

q_theme_df = pd.DataFrame(rows)
q_theme_df.head()
# Out:
#                                             question            theme
# 0  Quelle est la production de maïs en 2024 et co...  market_question
# 1  Quelle région a enregistré la plus forte augme...  market_question
# 2             Quel est le prix de référence du blé ?  market_question
# 3  Quelle est la répartition des volumes collecté...  market_question
# 4  Quelle est la variation des exportations de ri...  market_question

# %%
import pandas as pd

question_theme_pairs_df = q_theme_df
print(f"Number of lines before removing duplicates : {len(question_theme_pairs_df)}")


question_theme_pairs_df = question_theme_pairs_df.drop_duplicates(subset=['question', 'theme'])

print(f"Number of lines : {len(question_theme_pairs_df)}")
print(question_theme_pairs_df['theme'].value_counts())

question_theme_pairs_df
# Out:
# Number of lines before removing duplicates : 3000
# Number of lines : 1922
# theme
# market_question       481
# weather_management    473
# policy_help           399
# other                 352
# disease_diagnosis     217
# Name: count, dtype: int64
#                                                question            theme
# 0     Quelle est la production de maïs en 2024 et co...  market_question
# 1     Quelle région a enregistré la plus forte augme...  market_question
# 2                Quel est le prix de référence du blé ?  market_question
# 3     Quelle est la répartition des volumes collecté...  market_question
# 4     Quelle est la variation des exportations de ri...  market_question
# ...                                                 ...              ...
# 2992  Quels sont les critères à considérer pour choi...            other
# 2994  Quelles sont les techniques de stockage des ré...            other
# 2995  Comment gérer les risques climatiques en agric...            other
# 2998  Quelles sont les innovations récentes en matiè...            other
# 2999  Comment évaluer l'impact environnemental de so...            other
#
# [1922 rows x 2 columns]

# %%
from typing import Literal
from pydantic import BaseModel

class Theme(BaseModel):
    theme: Literal["market_question", "policy_help", "disease_diagnosis", "weather_management", "other"]

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(
    question_theme_pairs_df,
    test_size=0.1,
    stratify=question_theme_pairs_df['theme']
)

print(f"Train set size: {len(train_df)}")
print(f"Test set size: {len(test_df)}")
print("Train class distribution:\n", train_df['theme'].value_counts())
print("Test class distribution:\n", test_df['theme'].value_counts())
# Out:
# Train set size: 1729
# Test set size: 193
# Train class distribution:
#  theme
# market_question       433
# weather_management    425
# policy_help           359
# other                 317
# disease_diagnosis     195
# Name: count, dtype: int64
# Test class distribution:
#  theme
# market_question       48
# weather_management    48
# policy_help           40
# other                 35
# disease_diagnosis     22
# Name: count, dtype: int64

# %% [markdown]
# # Evaluation of ministral-3b

# %%
from tqdm import tqdm
import time

def predict(question, model):    
    prompt = (
        "Classify the following question into one of the following themes: "
        "'market_question', policy_help, disease_diagnosis, weather_management, other.\n\n"
        f"Question: {question}\n\nTheme:"
    )
    response = client.chat.parse(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        response_format=Theme,
    )
    return response.choices[0].message.parsed.theme

def evaluate_model(test_data_df, model):
    y_true = test_data_df["theme"].tolist()
    y_pred = []
    for i, q in enumerate(tqdm(test_data_df["question"], desc="Evaluating")):
        if i > 0 and i % 5 == 0: # Sleep every 5 iterations to avoid rate limiting
            time.sleep(2)
        y_pred.append(predict(q, model))

    themes = ["market_question", "policy_help", "disease_diagnosis", "weather_management", "other"]
    metrics = {}
    for theme in themes:
        tp = sum((yt == theme) and (yp == theme) for yt, yp in zip(y_true, y_pred))
        fp = sum((yt != theme) and (yp == theme) for yt, yp in zip(y_true, y_pred))
        fn = sum((yt == theme) and (yp != theme) for yt, yp in zip(y_true, y_pred))
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
        metrics[theme] = {"precision": precision, "recall": recall, "f1": f1}
    macro_avg = {
        k: sum(metrics[t][k] for t in themes) / len(themes)
        for k in ["precision", "recall", "f1"]
    }
    return {"per_class": metrics, "macro_avg": macro_avg}

results = evaluate_model(test_df, model="ministral-3b-latest")

print("Model evaluation results:")
print(f"Macro Average: Precision: {results['macro_avg']['precision']:.3f}, Recall: {results['macro_avg']['recall']:.3f}, F1: {results['macro_avg']['f1']:.3f}")
print("\nPer-class metrics:")
for theme, m in results['per_class'].items():
    print(f"{theme}: F1 = {m['f1']:.3f}")
# Out:
# Evaluating: 100%|██████████| 166/166 [02:37<00:00,  1.05it/s]
# Model evaluation results:
# Macro Average: Precision: 0.743, Recall: 0.752, F1: 0.745
#
# Per-class metrics:
# market_question: F1 = 0.784
# policy_help: F1 = 0.783
# disease_diagnosis: F1 = 0.914
# weather_management: F1 = 0.909
# other: F1 = 0.333

# %% [markdown]
# # Finetuning

# %%
from tqdm import tqdm
import json

def dataset_to_jsonl(dataset, output_file):
    # Open the output file in write mode
    with open(output_file, "w") as f:
        # Iterate over each row in the dataset
        for _, row in tqdm(dataset.iterrows(), total=dataset.shape[0]):
            # Extract the text and label from the row
            question = row["question"]
            theme = row["theme"]

            # Create the JSON object with the desired structure
            json_object = {"text": question, "labels": {"intent": theme}}

            # Write the JSON object to the file as a JSON line
            f.write(json.dumps(json_object) + "\n")

# Save files
dataset_to_jsonl(train_df, "train.jsonl")
dataset_to_jsonl(test_df, "test.jsonl")
# Out:
# 100%|██████████| 1488/1488 [00:00<00:00, 47643.99it/s]
# 100%|██████████| 166/166 [00:00<00:00, 49049.28it/s]

# %%
# Upload the training data
training_data = client.files.upload(
    file={
        "file_name": "train.jsonl",
        "content": open("train.jsonl", "rb"),
    }
)

# Upload the validation data
validation_data = client.files.upload(
    file={
        "file_name": "validation.jsonl",
        "content": open("test.jsonl", "rb"),
    }
)

# %%
# Create a fine-tuning job
wandb_key = os.getenv("WANDB_KEY")

created_job = client.fine_tuning.jobs.create(
    model="ministral-3b-latest",
    job_type="classifier",
    training_files=[{"file_id": training_data.id, "weight": 1}],
    validation_files=[validation_data.id],
    suffix="agro-intent-clf",
    hyperparameters={"training_steps": 50, "learning_rate":0.0001},
    auto_start=True,
    integrations=[
        {
            "project": "intent-classifier",
            "api_key": wandb_key,
        }
    ]
)
print(json.dumps(created_job.model_dump(), indent=4))
# Out:
# {
#     "id": "a0b2cfa8-0719-44e6-961a-d5c7c12fbc28",
#     "auto_start": true,
#     "model": "ministral-3b-latest",
#     "status": "QUEUED",
#     "created_at": 1745298997,
#     "modified_at": 1745298997,
#     "training_files": [
#         "ac308888-4430-499b-b327-5bac94743e9a"
#     ],
#     "hyperparameters": {
#         "training_steps": 50,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": null,
#         "seq_len": 16384
#     },
#     "validation_files": [
#         "16bda9a9-ca7a-44fb-80c3-a523cbd677b1"
#     ],
#     "object": "job",
#     "fine_tuned_model": null,
#     "suffix": "agro-intent-clf",
#     "integrations": [
#         {
#             "project": "intent-classifier",
#             "type": "wandb",
#             "name": null,
#             "run_name": null,
#             "url": null
#         }
#     ],
#     "trained_tokens": null,
#     "metadata": {
#         "expected_duration_seconds": null,
#         "cost": 0.0,
#         "cost_currency": null,
#         "train_tokens_per_step": null,
#         "train_tokens": null,
#         "data_tokens": null,
#         "estimated_start_time": null
#     },
#     "job_type": "classifier"
# }

# %%
# Retrieve the job details again
retrieved_job = client.fine_tuning.jobs.get(job_id=created_job.id)
print(json.dumps(retrieved_job.model_dump(), indent=4))
# Out:
# {
#     "id": "a0b2cfa8-0719-44e6-961a-d5c7c12fbc28",
#     "auto_start": true,
#     "model": "ministral-3b-latest",
#     "status": "SUCCESS",
#     "created_at": 1745298997,
#     "modified_at": 1745299106,
#     "training_files": [
#         "ac308888-4430-499b-b327-5bac94743e9a"
#     ],
#     "hyperparameters": {
#         "training_steps": 50,
#         "learning_rate": 0.0001,
#         "weight_decay": 0.1,
#         "warmup_fraction": 0.05,
#         "epochs": 56.95810881279333,
#         "seq_len": 16384
#     },
#     "classifier_targets": [
#         {
#             "name": "intent",
#             "labels": [
#                 "weather_management",
#                 "disease_diagnosis",
#                 "market_question",
#                 "other",
#                 "policy_help"
#             ],
#             "weight": 1.0,
#             "loss_function": "single_class"
#         }
#     ],
#     "validation_files": [
#         "16bda9a9-ca7a-44fb-80c3-a523cbd677b1"
#     ],
#     "object": "job",
#     "fine_tuned_model": "ft:classifier:ministral-3b-latest:82f3f89c:20250422:agro-intent-clf:a0b2cfa8",
#     "suffix": "agro-intent-clf",
#     "integrations": [
#         {
#             "project": "intent-classifier",
#             "type": "wandb",
#             "name": null,
#             "run_name": null,
#             "url": "https://wandb.ai/estienne-t-l-com-paris/intent-classifier/runs/o3xnfkj2"
#         }
#     ],
#     "trained_tokens": 819200,
#     "metadata": {
#         "expected_duration_seconds": 750,
#         "cost": 1.64,
#         "cost_currency": "EUR",
#         "train_tokens_per_step": 65536,
#         "train_tokens": 3276800,
#         "data_tokens": 57530,
#         "estimated_start_time": null
#     },
#     "job_type": "classifier",
#     "events": [
#         {
#             "name": "status-updated",
#             "created_at": 1745298997,
#             "data": {
#                 "status": "QUEUED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1745298999,
#             "data": {
#                 "status": "VALIDATING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1745298999,
#             "data": {
#                 "status": "VALIDATED"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1745299002,
#             "data": {
#                 "status": "RUNNING"
#             }
#         },
#         {
#             "name": "status-updated",
#             "created_at": 1745299106,
#             "data": {
#                 "status": "SUCCESS"
#             }
#         }
#     ],
#     "checkpoints": [
#         {
#             "metrics": {
#                 "train_loss": 2.9e-05,
#                 "valid_loss": 0.000729,
#                 "valid_mean_token_accuracy": 1.000505
#             },
#             "step_number": 50,
#             "created_at": 1745299085
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.9e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 49,
#             "created_at": 1745299085
#         },
#         {
#             "metrics": {
#                 "train_loss": 3e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 48,
#             "created_at": 1745299085
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.9e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 47,
#             "created_at": 1745299085
#         },
#         {
#             "metrics": {
#                 "train_loss": 2e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 46,
#             "created_at": 1745299085
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.7e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 45,
#             "created_at": 1745299085
#         },
#         {
#             "metrics": {
#                 "train_loss": 2e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 44,
#             "created_at": 1745299075
#         },
#         {
#             "metrics": {
#                 "train_loss": 4.3e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 43,
#             "created_at": 1745299075
#         },
#         {
#             "metrics": {
#                 "train_loss": 2e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 42,
#             "created_at": 1745299075
#         },
#         {
#             "metrics": {
#                 "train_loss": 3.3e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 41,
#             "created_at": 1745299075
#         },
#         {
#             "metrics": {
#                 "train_loss": 1.9e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 40,
#             "created_at": 1745299075
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.1e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 39,
#             "created_at": 1745299075
#         },
#         {
#             "metrics": {
#                 "train_loss": 3.5e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 38,
#             "created_at": 1745299075
#         },
#         {
#             "metrics": {
#                 "train_loss": 3.2e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 37,
#             "created_at": 1745299065
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.6e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 36,
#             "created_at": 1745299065
#         },
#         {
#             "metrics": {
#                 "train_loss": 4.4e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 35,
#             "created_at": 1745299065
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.3e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 34,
#             "created_at": 1745299065
#         },
#         {
#             "metrics": {
#                 "train_loss": 3.9e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 33,
#             "created_at": 1745299065
#         },
#         {
#             "metrics": {
#                 "train_loss": 4e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 32,
#             "created_at": 1745299065
#         },
#         {
#             "metrics": {
#                 "train_loss": 3.1e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 31,
#             "created_at": 1745299065
#         },
#         {
#             "metrics": {
#                 "train_loss": 4.9e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 30,
#             "created_at": 1745299065
#         },
#         {
#             "metrics": {
#                 "train_loss": 2.8e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 29,
#             "created_at": 1745299055
#         },
#         {
#             "metrics": {
#                 "train_loss": 4.9e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 28,
#             "created_at": 1745299055
#         },
#         {
#             "metrics": {
#                 "train_loss": 7.5e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 27,
#             "created_at": 1745299055
#         },
#         {
#             "metrics": {
#                 "train_loss": 4.7e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 26,
#             "created_at": 1745299055
#         },
#         {
#             "metrics": {
#                 "train_loss": 5.8e-05,
#                 "valid_loss": 0.00062,
#                 "valid_mean_token_accuracy": 1.00043
#             },
#             "step_number": 25,
#             "created_at": 1745299055
#         },
#         {
#             "metrics": {
#                 "train_loss": 8.2e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 24,
#             "created_at": 1745299055
#         },
#         {
#             "metrics": {
#                 "train_loss": 5.5e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 23,
#             "created_at": 1745299055
#         },
#         {
#             "metrics": {
#                 "train_loss": 9.8e-05,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 22,
#             "created_at": 1745299045
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000106,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 21,
#             "created_at": 1745299045
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000117,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 20,
#             "created_at": 1745299045
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000107,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 19,
#             "created_at": 1745299045
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000163,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 18,
#             "created_at": 1745299045
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.00017,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 17,
#             "created_at": 1745299045
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000221,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 16,
#             "created_at": 1745299045
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000244,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 15,
#             "created_at": 1745299035
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000336,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 14,
#             "created_at": 1745299035
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000443,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 13,
#             "created_at": 1745299035
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.00053,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 12,
#             "created_at": 1745299035
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000673,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 11,
#             "created_at": 1745299035
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000823,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 10,
#             "created_at": 1745299035
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.000937,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 9,
#             "created_at": 1745299035
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.001183,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 8,
#             "created_at": 1745299035
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.0013,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 7,
#             "created_at": 1745299025
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.001427,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 6,
#             "created_at": 1745299025
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.001574,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 5,
#             "created_at": 1745299025
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.00173,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 4,
#             "created_at": 1745299025
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.002,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 3,
#             "created_at": 1745299025
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.002197,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 2,
#             "created_at": 1745299025
#         },
#         {
#             "metrics": {
#                 "train_loss": 0.002178,
#                 "valid_loss": 0.0,
#                 "valid_mean_token_accuracy": 0.0
#             },
#             "step_number": 1,
#             "created_at": 1745299025
#         }
#     ]
# }

# %%
# Load the test samples
with open("test.jsonl", "r") as f:
    test_samples = [json.loads(l) for l in f.readlines()]

# Classify the first test sample
classifier_response = client.classifiers.classify(
    model=retrieved_job.fine_tuned_model,
    inputs=[test_samples[1]["text"]],
)
print("Text:", test_samples[1]["text"])
print("Classifier Response:", json.dumps(classifier_response.model_dump(), indent=4))
# Out:
# Text: Quelles sont les obligations de rotation des cultures pour les exploitations recevant des aides publiques ?
# Classifier Response: {
#     "id": "a4506bd4d7cd4bc2b24d16376cd89989",
#     "model": "ft:classifier:ministral-3b-latest:82f3f89c:20250422:agro-intent-clf:a0b2cfa8",
#     "results": [
#         {
#             "intent": {
#                 "scores": {
#                     "weather_management": 4.1807697925833054e-07,
#                     "disease_diagnosis": 9.930199240670845e-08,
#                     "market_question": 8.699067984707654e-05,
#                     "other": 1.2704710570687894e-05,
#                     "policy_help": 0.9998997449874878
#                 }
#             }
#         }
#     ]
# }

# %%
from tqdm import tqdm
import time

def predict(question):    
    response = client.classifiers.classify(
        model=retrieved_job.fine_tuned_model,
        inputs=[question],
    )
    scores = response.results[0]['intent'].scores
    predicted_label = max(scores, key=scores.get)

    return predicted_label

def evaluate_model(test_data_df):
    y_true = test_data_df["theme"].tolist()
    y_pred = []
    for i, q in enumerate(tqdm(test_data_df["question"], desc="Evaluating")):
        if i > 0 and i % 5 == 0: # Sleep every 5 iterations to avoid rate limiting
            time.sleep(2)
        y_pred.append(predict(q))

    themes = ["market_question", "policy_help", "disease_diagnosis", "weather_management", "other"]
    metrics = {}
    for theme in themes:
        tp = sum((yt == theme) and (yp == theme) for yt, yp in zip(y_true, y_pred))
        fp = sum((yt != theme) and (yp == theme) for yt, yp in zip(y_true, y_pred))
        fn = sum((yt == theme) and (yp != theme) for yt, yp in zip(y_true, y_pred))
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
        metrics[theme] = {"precision": precision, "recall": recall, "f1": f1}
    macro_avg = {
        k: sum(metrics[t][k] for t in themes) / len(themes)
        for k in ["precision", "recall", "f1"]
    }
    return {"per_class": metrics, "macro_avg": macro_avg}

results = evaluate_model(test_df)

print("Model evaluation results:")
print(f"Macro Average: Precision: {results['macro_avg']['precision']:.3f}, Recall: {results['macro_avg']['recall']:.3f}, F1: {results['macro_avg']['f1']:.3f}")
print("\nPer-class metrics:")
for theme, m in results['per_class'].items():
    print(f"{theme}: F1 = {m['f1']:.3f}")
# Out:
# Evaluating: 100%|██████████| 166/166 [02:03<00:00,  1.34it/s]
# Model evaluation results:
# Macro Average: Precision: 0.974, Recall: 0.961, F1: 0.967
#
# Per-class metrics:
# market_question: F1 = 0.971
# policy_help: F1 = 0.987
# disease_diagnosis: F1 = 1.000
# weather_management: F1 = 1.000
# other: F1 = 0.875
